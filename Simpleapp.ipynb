# %% [markdown]
# ## Simple Gen Ai App

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']='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'
os.environ['LANGCHAIN_API_KEY']='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'
os.environ['LANGCHAIN_TRACKING_V2']='True'
os.environ['LANGCHAIN_PROJECT']='default'

# %%
## Data Ingestion--From the website we need to scrape the data
from langchain_community.document_loaders import WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader=WebBaseLoader("https://www.rbi.org.in/commonman/english/scripts/Notification.aspx?Id=1574")
loader

# %%
docs=loader.load()
docs
# Out:
# [Document(metadata={'source': 'https://www.rbi.org.in/commonman/english/scripts/Notification.aspx?Id=1574', 'title': 'Reserve Bank of India', 'language': 'No language found.'}, page_content='\n\n\n\nReserve Bank of India\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0\r\n                        \r\n                    \n\n\n\n\n\nSELECT LANGUAGE\nASSAMESE\nBENGALI\nENGLISH\nGUJARATI\nHINDI\nKANNADA\nMALAYALAM\nMARATHI\nODIA\nPUNJABI\nTAMIL\nTELUGU\nURDU\n\n\n\n\xa0\r\n                        \r\n                    \n\n\n\n\nSITE MAP\xa0\xa0\xa0\xa0\r\n                            CONTACT US\xa0\xa0\xa0\xa0\r\n                            DISCLAIMER\xa0\xa0\n\n\n\n\n\n\n\n\n\n\r\n            \xa0\xa0 About Us\xa0\xa0\xa0\xa0\r\n            Useful\xa0Information\xa0\xa0\xa0\xa0\r\n\r\n            FAQs\xa0\xa0\xa0\xa0\r\n\r\n            Financial Education\xa0\xa0\xa0\xa0\r\n\r\n            Complaints\xa0\xa0\r\n\r\n            Important Websites\xa0\xa0\r\n  
# ...

# %%
### Load Data--> Docs-->Divide our Docuemnts into chunks dcouments-->text-->vectors-->Vector Embeddings--->Vector Store DB
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
documents=text_splitter.split_documents(docs)

# %%
documents
# Out:
# [Document(metadata={'source': 'https://www.rbi.org.in/commonman/english/scripts/Notification.aspx?Id=1574', 'title': 'Reserve Bank of India', 'language': 'No language found.'}, page_content='Reserve Bank of India\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0\r\n                        \r\n                    \n\n\n\n\n\nSELECT LANGUAGE\nASSAMESE\nBENGALI\nENGLISH\nGUJARATI\nHINDI\nKANNADA\nMALAYALAM\nMARATHI\nODIA\nPUNJABI\nTAMIL\nTELUGU\nURDU\n\n\n\n\xa0\r\n                        \r\n                    \n\n\n\n\nSITE MAP\xa0\xa0\xa0\xa0\r\n                            CONTACT US\xa0\xa0\xa0\xa0\r\n                            DISCLAIMER\xa0\xa0\n\n\n\n\n\n\n\n\n\n\r\n            \xa0\xa0 About Us\xa0\xa0\xa0\xa0\r\n            Useful\xa0Information\xa0\xa0\xa0\xa0\r\n\r\n            FAQs\xa0\xa0\xa0\xa0\r\n\r\n            Financial Education\xa0\xa0\xa0\xa0\r\n\r\n            Complaints\xa0\xa0\r\n\r\n            Important Websites\xa0\xa0\r\n          
# ...

# %%
from langchain_openai import OpenAIEmbeddings
embeddings=OpenAIEmbeddings()

# %%
from langchain_community.vectorstores import FAISS
vectorstoredb=FAISS.from_documents(documents,embeddings)

# %%
query="What is rbi?"
result=vectorstoredb.similarity_search(query)
result[0].page_content
# Out:
# 'Reserve Bank of India\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0\r\n                        \r\n                    \n\n\n\n\n\nSELECT LANGUAGE\nASSAMESE\nBENGALI\nENGLISH\nGUJARATI\nHINDI\nKANNADA\nMALAYALAM\nMARATHI\nODIA\nPUNJABI\nTAMIL\nTELUGU\nURDU\n\n\n\n\xa0\r\n                        \r\n                    \n\n\n\n\nSITE MAP\xa0\xa0\xa0\xa0\r\n                            CONTACT US\xa0\xa0\xa0\xa0\r\n                            DISCLAIMER\xa0\xa0\n\n\n\n\n\n\n\n\n\n\r\n            \xa0\xa0 About Us\xa0\xa0\xa0\xa0\r\n            Useful\xa0Information\xa0\xa0\xa0\xa0\r\n\r\n            FAQs\xa0\xa0\xa0\xa0\r\n\r\n            Financial Education\xa0\xa0\xa0\xa0\r\n\r\n            Complaints\xa0\xa0\r\n\r\n            Important Websites\xa0\xa0\r\n            \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPeriod\n\n\n\n\n\nFrom\n\xa0\n\n\nTo\n\xa0\n\n\n\n\n\n\n\n\n\n\n\n\nArchives'

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o-mini")

# %%
## Retrieval Chain, Document chain

from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_template(
    """
Answer the following question based only on the provided context:
<context>
{context}
</context>


"""
)

document_chain=create_stuff_documents_chain(llm,prompt)
document_chain
# Out:
# RunnableBinding(bound=RunnableBinding(bound=RunnableAssign(mapper={
#   context: RunnableLambda(format_docs)
# }), kwargs={}, config={'run_name': 'format_inputs'}, config_factories=[])
# | ChatPromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, template='\nAnswer the following question based only on the provided context:\n<context>\n{context}\n</context>\n\n\n'), additional_kwargs={})])
# | ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x000001F1FFE1E480>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001F1FFE1F1D0>, root_client=<openai.OpenAI object at 0x000001F1ED99D8E0>, root_async_client=<openai.AsyncOpenAI object at 0x000001F1FFE1E4E0>, model_name='gpt-4o-mini', model_kwargs={}, openai_api_key=SecretStr('**********'))
# ...

# %%
from langchain_core.documents import Document
document_chain.invoke({
    'input':'what is rbi?',
    'context':[Document(metadata={'source': 'https://www.rbi.org.in/commonman/english/scripts/Notification.aspx?Id=1574', 'title': 'Reserve Bank of India', 'language': 'No language found.'}, page_content='Reserve Bank of India\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0\r\n                        \r\n                    \n\n\n\n\n\nSELECT LANGUAGE\nASSAMESE\nBENGALI\nENGLISH\nGUJARATI\nHINDI\nKANNADA\nMALAYALAM\nMARATHI\nODIA\nPUNJABI\nTAMIL\nTELUGU\nURDU\n\n\n\n\xa0\r\n                        \r\n                    \n\n\n\n\nSITE MAP\xa0\xa0\xa0\xa0\r\n                            CONTACT US\xa0\xa0\xa0\xa0\r\n                            DISCLAIMER\xa0\xa0\n\n\n\n\n\n\n\n\n\n\r\n            \xa0\xa0 About Us\xa0\xa0\xa0\xa0\r\n            Useful\xa0Information\xa0\xa0\xa0\xa0\r\n\r\n            FAQs\xa0\xa0\xa0\xa0\r\n\r\n            Financial Education\xa0\xa0\xa0\xa0\r\n\r\n            Complaints\xa0\xa0\r\n\r\n            Important Websites\xa0\xa0\r\n            \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPeriod\n\n\n\n\n\nFrom\n\xa0\n\n\nTo\n\xa0\n\n\n\n\n\n\n\n\n\n\n\n\nArchives')]

})
# Out:
# 'What is the primary function of the Reserve Bank of India based on the provided context? \n\nThe provided context does not give specific information about the primary function of the Reserve Bank of India.'

# %%
retriever=vectorstoredb.as_retriever()

# %%
from langchain.chains import create_retrieval_chain
retrievel_chain=create_retrieval_chain(retriever,document_chain)

# %%
## GET Response from the LLM
response=retrievel_chain.invoke({'input':'What is Reserve Bank of India?'})

# %%
response
# Out:
# {'input': 'What is Reserve Bank of India?',
# ...
